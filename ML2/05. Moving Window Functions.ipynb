# %%
# %matplotlib inline
import matplotlib.pylab

# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)

import numpy as np
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # The special thing about time series is that data points relate to one another...they are not independent
# So we can to compare them and relate them. One way to do this is to look at how they change. For example, we can 'difference' a time series

# %%
ts = pd.Series(np.random.randn(20), pd.date_range('7/1/16', freq = 'D', periods = 20))
ts_lagged = ts.shift()

# %%
plt.plot(ts, color = 'blue')
plt.plot(ts_lagged, color = 'red')

# %% [markdown]
# ### Query: how can I shift my time series 'into the future' instead of into the past?

# %%
# %load snippets/shift_future.py
ts_lagged = ts.shift(-1)
plt.plot(ts, color = 'blue')
plt.plot(ts_lagged, color = 'red')

# %% [markdown]
# # Window functions give you moving aggregate measures of a time series

# %%
# Window functions are like aggregation functions
# You can use them in conjunction with .resample()

# %%
df = pd.DataFrame(np.random.randn(600, 3), index = pd.date_range('5/1/2016', freq = 'D', periods = 600), columns = ['A', 'B', 'C'])

# %%
r = df.rolling(window = 20)
r
# Out:
# Rolling [window=20,center=False,axis=0]

# %%
df['A'].plot(color = 'gray')
r.mean()['A'].plot(color = 'red')

# %% [markdown]
# ### Try out some of these options with .rolling()
#
# r.agg, r.apply, r.count, r.max, r.median, r.name, r.quantile, r.kurt,
# r.aggregate, r.std, r.skew, r.sum, r.var

# %%
df['A'].plot(color = 'gray')
r.median()['A'].plot(color = 'red')

# %% [markdown]
# ### What about a custom function?

# %%
# %load snippets/custom_rolling.py
r.apply(lambda x: max(x) - min(x))
# Out:
#                    A         B         C
# 2016-05-01       NaN       NaN       NaN
# 2016-05-02       NaN       NaN       NaN
# 2016-05-03       NaN       NaN       NaN
# 2016-05-04       NaN       NaN       NaN
# 2016-05-05       NaN       NaN       NaN
# 2016-05-06       NaN       NaN       NaN
# 2016-05-07       NaN       NaN       NaN
# 2016-05-08       NaN       NaN       NaN
# 2016-05-09       NaN       NaN       NaN
# 2016-05-10       NaN       NaN       NaN
# 2016-05-11       NaN       NaN       NaN
# 2016-05-12       NaN       NaN       NaN
# 2016-05-13       NaN       NaN       NaN
# 2016-05-14       NaN       NaN       NaN
# 2016-05-15       NaN       NaN       NaN
# 2016-05-16       NaN       NaN       NaN
# 2016-05-17       NaN       NaN       NaN
# 2016-05-18       NaN       NaN       NaN
# 2016-05-19       NaN       NaN       NaN
# 2016-05-20  3.788866  3.098180  3.908105
# 2016-05-21  3.788866  3.098180  3.908105
# 2016-05-22  3.788866  3.098180  3.908105
# 2016-05-23  3.788866  3.098180  3.908105
# 2016-05-24  3.788866  3.098180  3.483721
# 2016-05-25  3.788866  3.139050  3.483721
# 2016-05-26  3.788866  3.139050  3.823512
# 2016-05-27  3.788866  3.139050  3.823512
# 2016-05-28  3.788866  3.139050  3.823512
# 2016-05-29  3.788866  3.139050  3.823512
# 2016-05-30  3.788866  3.139050  3.823512
# ...              ...       ...       ...
# 2017-11-22  3.861143  3.876456  4.128864
# 2017-11-23  3.861143  3.876456  4.128864
# 2017-11-24  3.861143  3.876456  4.128864
# 2017-11-25  3.861143  3.876456  4.128864
# 2017-11-26  3.790006  3.876456  2.603915
# 2017-11-27  3.790006  3.876456  2.603915
# 2017-11-28  3.790006  3.876456  2.603915
# 2017-11-29  3.790006  3.876456  3.174719
# 2017-11-30  3.790006  3.876456  3.174719
# 2017-12-01  3.631389  3.876456  3.174719
# 2017-12-02  3.631389  3.876456  3.174719
# 2017-12-03  3.631389  3.580500  3.174719
# 2017-12-04  3.631389  3.580500  3.174719
# 2017-12-05  3.205254  3.580500  3.320167
# 2017-12-06  3.205254  3.580500  3.320167
# 2017-12-07  3.205254  3.456709  3.320167
# 2017-12-08  3.205254  3.456709  3.320167
# 2017-12-09  3.205254  3.328567  3.320167
# 2017-12-10  4.004473  3.328567  3.320167
# 2017-12-11  4.004473  3.328567  3.320167
# 2017-12-12  4.004473  3.328567  3.320167
# 2017-12-13  4.004473  2.863815  3.320167
# 2017-12-14  4.004473  2.863815  3.320167
# 2017-12-15  4.004473  2.863815  3.617659
# 2017-12-16  4.004473  2.863815  2.761220
# 2017-12-17  3.310607  3.083583  2.761220
# 2017-12-18  3.310607  3.083583  2.761220
# 2017-12-19  3.310607  3.266737  2.761220
# 2017-12-20  3.310607  3.266737  3.303375
# 2017-12-21  3.310607  3.266737  3.303375
#
# [600 rows x 3 columns]

# %% [markdown]
# ### What if I want to generate a rolling window function of monthly data from daily data?

# %%
# %load snippets/resample_rolling.py
ts_long = pd.Series(np.random.randn(200), pd.date_range('7/1/2016', freq = "D", periods = 200))
ts_long.resample("M").mean().rolling(window = 3).mean().plot()

# %% [markdown]
# ## Expanding windows

# %%
df.expanding(min_periods = 1).mean()[1:5]
# Out:
#                    A         B         C
# 2016-05-02 -0.972709  0.235308 -0.455130
# 2016-05-03 -0.400864 -0.447342 -0.164630
# 2016-05-04 -0.427968 -0.344337 -0.578729
# 2016-05-05 -0.467588 -0.441747 -0.382781

# %%
df.expanding(min_periods = 1).mean().plot()

# %% [markdown]
# # Try

# %% [markdown]
# (1) How can you perform an exponentially weight moving average rather than a window function? (hint: look for ewma + pandas docs)
#
# (2) When would you use an expanding window vs. a rolling window?
#
# (3) Write a custom function to repace .quantile(.5) function for a moving average
#
# (4) How would you compute more than one aggregation function on a moving window function at the same time?

# %%
# %load snippets/window_funcs_try.py
ts = pd.Series(np.random.randn(1000), index = pd.date_range(start = '1/1/16', periods = 1000, freq = 'D'))
ts.ewm(span = 60, freq = 'D', min_periods = 0, adjust = True).mean().plot()
ts.rolling(window = 60).mean().plot()

# %% [markdown]
# To decrease variation in the estimate

# %%
r = df.rolling(window = 20)
r.apply(lambda x: sorted(x)[round(len(x)*.5)])
# Out:
#                    A         B         C
# 2016-05-01       NaN       NaN       NaN
# 2016-05-02       NaN       NaN       NaN
# 2016-05-03       NaN       NaN       NaN
# 2016-05-04       NaN       NaN       NaN
# 2016-05-05       NaN       NaN       NaN
# 2016-05-06       NaN       NaN       NaN
# 2016-05-07       NaN       NaN       NaN
# 2016-05-08       NaN       NaN       NaN
# 2016-05-09       NaN       NaN       NaN
# 2016-05-10       NaN       NaN       NaN
# 2016-05-11       NaN       NaN       NaN
# 2016-05-12       NaN       NaN       NaN
# 2016-05-13       NaN       NaN       NaN
# 2016-05-14       NaN       NaN       NaN
# 2016-05-15       NaN       NaN       NaN
# 2016-05-16       NaN       NaN       NaN
# 2016-05-17       NaN       NaN       NaN
# 2016-05-18       NaN       NaN       NaN
# 2016-05-19       NaN       NaN       NaN
# 2016-05-20 -0.179267  0.006906 -0.183536
# 2016-05-21  0.151930 -0.035321  0.209989
# 2016-05-22  0.151930 -0.035321  0.209989
# 2016-05-23 -0.179267 -0.035321 -0.183536
# 2016-05-24 -0.179267 -0.117722  0.209989
# 2016-05-25 -0.179267 -0.117722  0.058406
# 2016-05-26 -0.179267 -0.031827  0.058406
# 2016-05-27 -0.179267 -0.088656  0.209989
# 2016-05-28 -0.179267 -0.088656  0.209989
# 2016-05-29 -0.324926 -0.088656  0.058406
# 2016-05-30 -0.324926 -0.117722 -0.183536
# ...              ...       ...       ...
# 2017-11-22  0.088580 -0.022189 -0.171348
# 2017-11-23  0.088580 -0.022189 -0.171348
# 2017-11-24  0.088580 -0.022189 -0.255743
# 2017-11-25  0.088580 -0.022189 -0.255743
# 2017-11-26  0.088580 -0.029528 -0.306551
# 2017-11-27 -0.276340 -0.029528 -0.306551
# 2017-11-28 -0.276340 -0.029528 -0.306551
# 2017-11-29  0.088580 -0.022189 -0.306551
# 2017-11-30  0.088580  0.164603 -0.255743
# 2017-12-01  0.122350 -0.022189 -0.255743
# 2017-12-02  0.122350 -0.069948 -0.241472
# 2017-12-03  0.366504 -0.022189 -0.255743
# 2017-12-04  0.366504 -0.069948 -0.306551
# 2017-12-05  0.122350 -0.073546 -0.255743
# 2017-12-06  0.122350 -0.138116 -0.306551
# 2017-12-07  0.088580 -0.138116 -0.310415
# 2017-12-08  0.088580 -0.146805 -0.255743
# 2017-12-09  0.088580 -0.146805 -0.310415
# 2017-12-10  0.088580 -0.213415 -0.310415
# 2017-12-11  0.314636 -0.213415 -0.255743
# 2017-12-12  0.314636 -0.213415 -0.255743
# 2017-12-13 -0.026734 -0.213415 -0.310415
# 2017-12-14 -0.075741 -0.146805 -0.310415
# 2017-12-15 -0.075741 -0.146805 -0.310415
# 2017-12-16 -0.075741 -0.073546 -0.155884
# 2017-12-17 -0.075741 -0.073546  0.116971
# 2017-12-18 -0.122910 -0.073546  0.116971
# 2017-12-19 -0.134013 -0.073546  0.116971
# 2017-12-20 -0.134013 -0.146805 -0.155884
# 2017-12-21 -0.134013 -0.146805 -0.155884
#
# [600 rows x 3 columns]

# %%
r = df.rolling(window = 20)
r.agg(['sum', 'count']).head()
# Out:
#              A         B         C
#            sum count sum count sum count
# 2016-05-01 NaN   1.0 NaN   1.0 NaN   1.0
# 2016-05-02 NaN   2.0 NaN   2.0 NaN   2.0
# 2016-05-03 NaN   3.0 NaN   3.0 NaN   3.0
# 2016-05-04 NaN   4.0 NaN   4.0 NaN   4.0
# 2016-05-05 NaN   5.0 NaN   5.0 NaN   5.0
